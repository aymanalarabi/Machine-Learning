# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for dirname, _, filenames in os.walk("C:\\Users\\ayman\\ML"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 for dirname, _, filenames in os.walk("C:\\Users\\ayman\\ML"):
#       2     for filename in filenames:
#       3         print(os.path.join(dirname, filename))
#
# NameError: name 'os' is not defined

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ayman\\ML'

# %%
import os

# %%
data = pd.read_csv('C:/Users/ayman/ML/pokemon.csv')
data= data.set_index("#")
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
df["capital"] = ["madrid","paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
df["income"] = 0 
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %%
data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()
# Out:
# <AxesSubplot:xlabel='#'>

# %%
data1.plot(subplots = True)
plt.show()

# %%
data1.plot(kind = "scatter",x="Attack",y = "Defense")
plt.show()

# %%
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:140, in HistPlot._make_plot(self)
#     137 if weights is not None and np.ndim(weights) != 1:
#     138     kwds["weights"] = weights[:, i]
# --> 140 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     142 # when by is applied, show title for subplots to know which group it is
#     143 if self.by is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:94, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      92 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      93 # ignore style
# ---> 94 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      95 cls._update_stacker(ax, stacking_id, n)
#      96 return patches
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 fig, axes = plt.subplots(nrows=2,ncols=1)
# ----> 2 data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[0])
#       3 data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[1],cumulative = True)
#       4 plt.savefig('graph.png')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:140, in HistPlot._make_plot(self)
#     137 if weights is not None and np.ndim(weights) != 1:
#     138     kwds["weights"] = weights[:, i]
# --> 140 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     142 # when by is applied, show title for subplots to know which group it is
#     143 if self.by is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:94, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      92 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      93 # ignore style
# ---> 94 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      95 cls._update_stacker(ax, stacking_id, n)
#      96 return patches
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
data.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1]))


datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65     45           1      False
# 1992-02-10       80     60           1      False
# 1992-03-10      100     80           1      False
# 1993-03-15      120     80           1      False
# 1993-03-16       50     65           1      False

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100     80           1      False
# 1993-03-15      120     80           1      False
# 1993-03-16       50     65           1      False

# %%
data2.resample("A").mean()
# Out:
#                    HP     Attack  Defense    Sp. Atk    Sp. Def      Speed  \
# date
# 1992-12-31  61.666667  64.333333     65.0  81.666667  81.666667  61.666667
# 1993-12-31  59.500000  76.000000     83.0  91.000000  85.000000  72.500000
#
#             Generation  Legendary
# date
# 1992-12-31         1.0        0.0
# 1993-12-31         1.0        0.0

# %%
data2.resample("M").mean()
# Out:
#               HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-12-31   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-01-31   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-02-28   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-03-31  59.5    76.0     83.0     91.0     85.0   72.5         1.0
#
#             Legendary
# date
# 1992-01-31        0.0
# 1992-02-29        0.0
# 1992-03-31        0.0
# 1992-04-30        NaN
# 1992-05-31        NaN
# 1992-06-30        NaN
# 1992-07-31        NaN
# 1992-08-31        NaN
# 1992-09-30        NaN
# 1992-10-31        NaN
# 1992-11-30        NaN
# 1992-12-31        NaN
# 1993-01-31        NaN
# 1993-02-28        NaN
# 1993-03-31        0.0

# %%
data2.resample("M").first().interpolate("linear")
# Out:
#                      Name Type 1  Type 2    HP  Attack     Defense  \
# date
# 1992-01-31      Bulbasaur  Grass  Poison  45.0    49.0   49.000000
# 1992-02-29        Ivysaur  Grass  Poison  60.0    62.0   63.000000
# 1992-03-31       Venusaur  Grass  Poison  80.0    82.0   83.000000
# 1992-04-30           None   None    None  80.0    83.5   86.333333
# 1992-05-31           None   None    None  80.0    85.0   89.666667
# 1992-06-30           None   None    None  80.0    86.5   93.000000
# 1992-07-31           None   None    None  80.0    88.0   96.333333
# 1992-08-31           None   None    None  80.0    89.5   99.666667
# 1992-09-30           None   None    None  80.0    91.0  103.000000
# 1992-10-31           None   None    None  80.0    92.5  106.333333
# 1992-11-30           None   None    None  80.0    94.0  109.666667
# 1992-12-31           None   None    None  80.0    95.5  113.000000
# 1993-01-31           None   None    None  80.0    97.0  116.333333
# 1993-02-28           None   None    None  80.0    98.5  119.666667
# 1993-03-31  Mega Venusaur  Grass  Poison  80.0   100.0  123.000000
#
#                Sp. Atk     Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-31   65.000000   65.000000   45.0         1.0        0.0
# 1992-02-29   80.000000   80.000000   60.0         1.0        0.0
# 1992-03-31  100.000000  100.000000   80.0         1.0        0.0
# 1992-04-30  101.833333  101.666667   80.0         1.0        0.0
# 1992-05-31  103.666667  103.333333   80.0         1.0        0.0
# 1992-06-30  105.500000  105.000000   80.0         1.0        0.0
# 1992-07-31  107.333333  106.666667   80.0         1.0        0.0
# 1992-08-31  109.166667  108.333333   80.0         1.0        0.0
# 1992-09-30  111.000000  110.000000   80.0         1.0        0.0
# 1992-10-31  112.833333  111.666667   80.0         1.0        0.0
# 1992-11-30  114.666667  113.333333   80.0         1.0        0.0
# 1992-12-31  116.500000  115.000000   80.0         1.0        0.0
# 1993-01-31  118.333333  116.666667   80.0         1.0        0.0
# 1993-02-28  120.166667  118.333333   80.0         1.0        0.0
# 1993-03-31  122.000000  120.000000   80.0         1.0        0.0

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#                    HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  Generation  \
# date
# 1992-01-31  45.000000    49.0     49.0    65.00    65.00  45.000         1.0
# 1992-02-29  60.000000    62.0     63.0    80.00    80.00  60.000         1.0
# 1992-03-31  80.000000    82.0     83.0   100.00   100.00  80.000         1.0
# 1992-04-30  78.291667    81.5     83.0    99.25    98.75  79.375         1.0
# 1992-05-31  76.583333    81.0     83.0    98.50    97.50  78.750         1.0
# 1992-06-30  74.875000    80.5     83.0    97.75    96.25  78.125         1.0
# 1992-07-31  73.166667    80.0     83.0    97.00    95.00  77.500         1.0
# 1992-08-31  71.458333    79.5     83.0    96.25    93.75  76.875         1.0
# 1992-09-30  69.750000    79.0     83.0    95.50    92.50  76.250         1.0
# 1992-10-31  68.041667    78.5     83.0    94.75    91.25  75.625         1.0
# 1992-11-30  66.333333    78.0     83.0    94.00    90.00  75.000         1.0
# 1992-12-31  64.625000    77.5     83.0    93.25    88.75  74.375         1.0
# 1993-01-31  62.916667    77.0     83.0    92.50    87.50  73.750         1.0
# 1993-02-28  61.208333    76.5     83.0    91.75    86.25  73.125         1.0
# 1993-03-31  59.500000    76.0     83.0    91.00    85.00  72.500         1.0
#
#             Legendary
# date
# 1992-01-31        0.0
# 1992-02-29        0.0
# 1992-03-31        0.0
# 1992-04-30        0.0
# 1992-05-31        0.0
# 1992-06-30        0.0
# 1992-07-31        0.0
# 1992-08-31        0.0
# 1992-09-30        0.0
# 1992-10-31        0.0
# 1992-11-30        0.0
# 1992-12-31        0.0
# 1993-01-31        0.0
# 1993-02-28        0.0
# 1993-03-31        0.0

# %%
data = pd.read_csv('C:/Users/ayman/ML/pokemon.csv')
data= data.set_index("#")
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
data["HP"][1]
# Out:
# 45

# %%
data.HP[1]
# Out:
# 45

# %%
data.loc[1,["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
data[["HP","Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 4    80     100
# 5    39      52
# ..   ..     ...
# 796  50     100
# 797  50     160
# 798  80     110
# 799  80     160
# 800  80     110
#
# [800 rows x 2 columns]

# %%
print(type(data["HP"]))     
print(type(data[["HP"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[1:10,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
data.loc[10:1:-1,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
data.loc[1:10,"Speed":]
# Out:
#     Speed  Generation  Legendary
# #
# 1      45           1      False
# 2      60           1      False
# 3      80           1      False
# 4      80           1      False
# 5      65           1      False
# 6      80           1      False
# 7     100           1      False
# 8     100           1      False
# 9     100           1      False
# 10     43           1      False

# %%
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122  Chansey  Normal    NaN  250       5        5       35      105     50
# 262  Blissey  Normal    NaN  255      10       10       75      135     55
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False

# %%
first_filter = data.HP > 150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal    NaN  250       5        5       35      105     50
# 262    Blissey  Normal    NaN  255      10       10       75      135     55
# 352    Wailord   Water    NaN  170      90       45       90       45     60
# 656  Alomomola   Water    NaN  165      75       80       40       45     65
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
data.HP[data.Speed<15]
# Out:
# #
# 231     20
# 360     45
# 487     50
# 496    135
# 659     44
# Name: HP, dtype: int64

# %%
def div(n):
    return n/2
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data.HP.apply(lambda n : n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %%
print(data.index.name)

data.index.name = "index_name"
data.head()
# Out:
# #
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 1                65     45           1      False           98
# 2                80     60           1      False          125
# 3               100     80           1      False          165
# 4               120     80           1      False          223
# 5                50     65           1      False           95

# %%
data.head()

data3 = data.copy()

data3.index = range(100,900,1)
data3.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101        Ivysaur  Grass  Poison  60      62       63       80       80
# 102       Venusaur  Grass  Poison  80      82       83      100      100
# 103  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100     45           1      False           98
# 101     60           1      False          125
# 102     80           1      False          165
# 103     80           1      False          223
# 104     65           1      False           95

# %%
data = pd.read_csv('C:/Users/ayman/ML/pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data1 = data.set_index(["Type 1","Type 2"]) 
data1.head(100)
# Out:
#                  #           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Grass  Poison    1      Bulbasaur   45      49       49       65       65
#        Poison    2        Ivysaur   60      62       63       80       80
#        Poison    3       Venusaur   80      82       83      100      100
#        Poison    4  Mega Venusaur   80     100      123      122      120
# Fire   NaN       5     Charmander   39      52       43       60       50
# ...            ...            ...  ...     ...      ...      ...      ...
# Poison NaN      96         Grimer   80      80       50       40       50
#        NaN      97            Muk  105     105       75       65      100
# Water  NaN      98       Shellder   30      65      100       45       25
#        Ice      99       Cloyster   50      95      180       85       45
# Ghost  Poison  100         Gastly   30      35       30      100       35
#
#                Speed  Generation  Legendary
# Type 1 Type 2
# Grass  Poison     45           1      False
#        Poison     60           1      False
#        Poison     80           1      False
#        Poison     80           1      False
# Fire   NaN        65           1      False
# ...              ...         ...        ...
# Poison NaN        25           1      False
#        NaN        50           1      False
# Water  NaN        40           1      False
#        Ice        70           1      False
# Ghost  Poison     80           1      False
#
# [100 rows x 10 columns]

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
df.pivot(index="treatment",columns = "gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %%
df1 = df.set_index(["treatment","gender"])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %%
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
df.groupby("treatment").mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
df.groupby("treatment")[["age","response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      object
#  1   gender     4 non-null      object
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes
